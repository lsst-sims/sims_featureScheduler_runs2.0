# %%
import numpy as np
import healpy as hp
# %matplotlib inline
import matplotlib,pylab as plt
from virgo_cluster import Virgo_map

# %%
nside=32
sm = Virgo_map(nside=nside)

# %%
sm.set_maps()
final_tot, footprints_hp = sm.return_maps()

# %%
hp.mollview(footprints_hp['r'], rot=[0,0,0])
