# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_pickle('combined_stats.pkl')

# %%
df.sort_index(inplace=True)
df
# Out:
# metric                                DifferentialCompleteness@Time@H=22.00 H = 22.0 @ 60218.00 Discovery_Time Vatira 3 pairs in 15 nights trailing loss MoObjSlicer  \
# run_name
# baseline_v2.0_10yrs                                                                 0.0
# twilight_neo_nightpattern1v2.0_10yrs                                                0.0
# twilight_neo_nightpattern2v2.0_10yrs                                                0.0
# twilight_neo_nightpattern3v2.0_10yrs                                                0.0
# twilight_neo_nightpattern4v2.0_10yrs                                                0.0
# twilight_neo_nightpattern5v2.0_10yrs                                                0.0
# twilight_neo_nightpattern6v2.0_10yrs                                                0.0
# twilight_neo_nightpattern7v2.0_10yrs                                                0.0
#
# ...

# %%
fig, ax = plt.subplots()
ax.plot(df['DifferentialCompleteness H = 16.000000 Discovery_N_Chances Vatira 3 pairs in 15 nights trailing loss MoObjSlicer']
 )
ack = ax.tick_params('x',  rotation=90)
ax.set_ylabel('Vatiras Completeness')
ax.set_title('H=16')
# Out:
# Text(0.5, 1.0, 'H=16')

# %%
fig, ax = plt.subplots()
ax.plot(df['DifferentialCompleteness H = 20.000000 Discovery_N_Chances Vatira 3 pairs in 15 nights trailing loss MoObjSlicer']
 )
ack = ax.tick_params('x',  rotation=90)
ax.set_ylabel('Vatiras Completeness')
ax.set_title('H=20')
# Out:
# Text(0.5, 1.0, 'H=20')
